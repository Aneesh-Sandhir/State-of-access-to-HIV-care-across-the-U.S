# %%
import pandas as pd
import numpy as np
import requests
import json
import topojson
import time

# %%
data = pd.read_csv("clinic_areas_1.csv")
data.head()
# Out:
#                                                Name  Longitude   Latitude  \
# 0               University of Alabama At Birmingham -86.799227  33.505740
# 1  Aids Action Coalition Of Huntsville/Davis Clinic -86.587402  34.722072
# 2                                  County of Mobile -88.054711  30.692269
# 3                       Whatley Health Services Inc -87.577417  33.187122
# 4                        Health Services Center Inc -85.826492  33.658764
#
#                                      hour_simplified  index  population
# 0  {"type": "Topology", "objects": {"data": {"geo...      0     1301777
# 1  {"type": "Topology", "objects": {"data": {"geo...      1      797770
# 2  {"type": "Topology", "objects": {"data": {"geo...      2      942217
# 3  {"type": "Topology", "objects": {"data": {"geo...      3      495469
# 4  {"type": "Topology", "objects": {"data": {"geo...      4      753866

# %%
data.to_csv('file.csv', index = False)

# %%
data = data.drop(columns = ['index', 'hour_simplified'])
data.head()
# Out:
#                                                Name  Longitude   Latitude  \
# 0               University of Alabama At Birmingham -86.799227  33.505740
# 1  Aids Action Coalition Of Huntsville/Davis Clinic -86.587402  34.722072
# 2                                  County of Mobile -88.054711  30.692269
# 3                       Whatley Health Services Inc -87.577417  33.187122
# 4                        Health Services Center Inc -85.826492  33.658764
#
#    population
# 0     1301777
# 1      797770
# 2      942217
# 3      495469
# 4      753866

# %%
identifier = []
service_area_geometries = []

API_Key = "5b3ce3597851110001cf6248255645d2de73474fb133bc9084349782"
for index, row in data.iterrows():
    identifier.append('clinic_' + str(index))
    
    body = {"locations":[[row['Longitude'], row['Latitude']]],
                "range":[3600],
                "range_type":"time",
                "smoothing":50}
    
    headers = {'Accept': 'application/json, application/geo+json, application/gpx+xml, img/png; charset=utf-8',
                'Authorization': API_Key}
    
    call = requests.post('https://api.openrouteservice.org/v2/isochrones/driving-car', json=body, headers=headers)
    service_area = json.loads(call.text)["features"][0]
    
    service_area_geometries.append(json.dumps(service_area))
    
    if ((index%4) == 0):
        print(str(index / 4) + "% complete" )
    time.sleep(3)
# Out:
# 0.0% complete
# 1.0% complete
# 2.0% complete
# 3.0% complete
# 4.0% complete
# 5.0% complete
# 6.0% complete
# 7.0% complete
# 8.0% complete
# 9.0% complete
# 10.0% complete
# 11.0% complete
# 12.0% complete
# 13.0% complete
# 14.0% complete
# 15.0% complete
# 16.0% complete
# 17.0% complete
# 18.0% complete
# 19.0% complete
# 20.0% complete
# 21.0% complete
# 22.0% complete
# 23.0% complete
# 24.0% complete
# 25.0% complete
# 26.0% complete
# 27.0% complete
# 28.0% complete
# 29.0% complete
# 30.0% complete
# 31.0% complete
# 32.0% complete
# 33.0% complete
# 34.0% complete
# 35.0% complete
# 36.0% complete
# 37.0% complete
# 38.0% complete
# 39.0% complete
# 40.0% complete
# 41.0% complete
# 42.0% complete
# 43.0% complete
# 44.0% complete
# 45.0% complete
# 46.0% complete
# 47.0% complete

# %%
data['hour_simplified'] = service_area_geometries
data['index'] = identifier
columns = ['index', 'Name', 'Longitude', 'Latitude', 'hour_simplified', 'population']

data = data[columns]
data.head()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-86-b48dcec0f1ac> in <module>
# ----> 1 data['hour_simplified'] = service_area_geometries
#       2 data['index'] = identifier
#       3 columns = ['index', 'Name', 'Longitude', 'Latitude', 'hour_simplified', 'population']
#       4
#       5 data = data[columns]
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\frame.py in __setitem__(self, key, value)
#    3368         else:
#    3369             # set column
# -> 3370             self._set_item(key, value)
#    3371
#    3372     def _setitem_slice(self, key, value):
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\frame.py in _set_item(self, key, value)
#    3443
#    3444         self._ensure_valid_index(value)
# -> 3445         value = self._sanitize_column(key, value)
#    3446         NDFrame._set_item(self, key, value)
#    3447
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\frame.py in _sanitize_column(self, key, value, broadcast)
#    3628
#    3629             # turn me into an ndarray
# -> 3630             value = sanitize_index(value, self.index, copy=False)
#    3631             if not isinstance(value, (np.ndarray, Index)):
#    3632                 if isinstance(value, list) and len(value) > 0:
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\internals\construction.py in sanitize_index(data, index, copy)
#     517
#     518     if len(data) != len(index):
# --> 519         raise ValueError('Length of values does not match length of index')
#     520
#     521     if isinstance(data, ABCIndexClass) and not copy:
#
# ValueError: Length of values does not match length of index

# %%
    
data['id'] = identifier
columns = ['id', 'Name', 'Longitude', 'Latitude', 'hour_simplified', 'population']
data = data[columns]
data.head()
# Out:
#              id                                               Name  \
# 0      clinic_0                University of Alabama At Birmingham
# 1      clinic_1   Aids Action Coalition Of Huntsville/Davis Clinic
# 2      clinic_2                                   County of Mobile
# 3      clinic_3                        Whatley Health Services Inc
# 4      clinic_4                         Health Services Center Inc
# 5      clinic_5                       Montgomery AIDS Outreach Inc
# 6      clinic_6                              Unity Wellness Center
# 7      clinic_7                                             Arcare
# 8      clinic_8            Jefferson Comprehensive Care System Inc
# 9      clinic_9             East Arkansas Family Health Center Inc
# 10    clinic_10       Maricopa County Special Health Care District
# 11    clinic_11                      Southwest Center For HIV/AIDS
# 12    clinic_12                              University of Arizona
# 13    clinic_13   El Rio Santa Cruz Neighborhood Health Center Inc
# 14    clinic_14                 Open Door Community Health Centers
# 15    clinic_15                         El Proyecto Del Barrio Inc
# 16    clinic_16                               Clinica Sierra Vista
# 17    clinic_17                Altamed Health Services Corporation
# 18    clinic_18                             Tri-City Health Center
# 19    clinic_19                      Alameda County Medical Center
# 20    clinic_20                          Alameda Health Consortium
# 21    clinic_21                              La Clinica De La Raza
# 22    clinic_22                              Lifelong Medical Care
# 23    clinic_23                              Asian Health Services
# 24    clinic_24  Community Special Services University Medical ...
# 25    clinic_25                     West County Health Centers Inc
# 26    clinic_26                 University Of California San Diego
# 27    clinic_27            Bartz-Altadonna Community Health Center
# 28    clinic_28     St. Mary Medical Center Care Program & Clinics
# 29    clinic_29  AIDS Healthcare Foundation - Jacksonville Florida
# ..          ...                                                ...
# 370  clinic_370                      Polk County Health Department
# 371  clinic_371                     Duval County Health Department
# 372  clinic_372                    Hendry County Health Department
# 373  clinic_373               Columbus Department of Public Health
# 374  clinic_374                                     County Houston
# 375  clinic_375                       Floyd County Board of Health
# 376  clinic_376                      Ware County Health Department
# 377  clinic_377                   Portland Community Health Center
# 378  clinic_378                           East Carolina University
# 379  clinic_379                   Wake County Department of Health
# 380  clinic_380                 Multnomah County Health Department
# 381  clinic_381                       Wyoming Department of Health
# 382  clinic_382                      Community Health Services Inc
# 383  clinic_383                  Okaloosa County Health Department
# 384  clinic_384                    Monroe County Health Department
# 385  clinic_385                   Mary Hitchcock Memorial Hospital
# 386  clinic_386                     Sunset Park Health Council Inc
# 387  clinic_387                 Low Country Health Care System Inc
# 388  clinic_388               Vanderbilt University Medical Center
# 389  clinic_389        San Bernardino County of Public Health Dept
# 390  clinic_390                               Staywell health care
# 391  clinic_391                                          Empower U
# 392  clinic_392                 St Johns County Health Department
# 393  clinic_393                     Laurens County Board of Health
# 394  clinic_394                                     County of Hall
# 395  clinic_395                                Community Healthnet
# 396  clinic_396               New orleans AIDS Task Force (NOAIDS)
# 397  clinic_397                    Minneapolis Hennepin Healthcare
# 398  clinic_398                  Pinnacle Health Medical Services
# 399  clinic_399                                     City of Laredo
#
#       Longitude   Latitude                                    hour_simplified  \
# 0    -86.799227  33.505740  {"type": "Topology", "objects": {"data": {"geo...
# 1    -86.587402  34.722072  {"type": "Topology", "objects": {"data": {"geo...
# 2    -88.054711  30.692269  {"type": "Topology", "objects": {"data": {"geo...
# 3    -87.577417  33.187122  {"type": "Topology", "objects": {"data": {"geo...
# 4    -85.826492  33.658764  {"type": "Topology", "objects": {"data": {"geo...
# 5    -86.262399  32.337279  {"type": "Topology", "objects": {"data": {"geo...
# 6    -85.403770  32.635608  {"type": "Topology", "objects": {"data": {"geo...
# 7    -91.366535  35.283400  {"type": "Topology", "objects": {"data": {"geo...
# 8    -91.998265  34.218269  {"type": "Topology", "objects": {"data": {"geo...
# 9    -90.175883  35.154972  {"type": "Topology", "objects": {"data": {"geo...
# 10  -112.026146  33.458511  {"type": "Topology", "objects": {"data": {"geo...
# 11  -112.073712  33.460508  {"type": "Topology", "objects": {"data": {"geo...
# 12  -110.959478  32.232825  {"type": "Topology", "objects": {"data": {"geo...
# 13  -110.985732  32.220400  {"type": "Topology", "objects": {"data": {"geo...
# 14  -124.085551  40.868867  {"type": "Topology", "objects": {"data": {"geo...
# 15  -118.437406  34.231320  {"type": "Topology", "objects": {"data": {"geo...
# 16  -119.018417  35.373870  {"type": "Topology", "objects": {"data": {"geo...
# 17  -118.155788  34.008703  {"type": "Topology", "objects": {"data": {"geo...
# 18  -121.977238  37.548401  {"type": "Topology", "objects": {"data": {"geo...
# 19  -122.231145  37.799164  {"type": "Topology", "objects": {"data": {"geo...
# 20  -122.156097  37.725918  {"type": "Topology", "objects": {"data": {"geo...
# 21  -122.225099  37.778220  {"type": "Topology", "objects": {"data": {"geo...
# 22  -122.295773  37.861987  {"type": "Topology", "objects": {"data": {"geo...
# 23  -122.271160  37.799506  {"type": "Topology", "objects": {"data": {"geo...
# 24  -119.783164  36.746523  {"type": "Topology", "objects": {"data": {"geo...
# 25  -122.998568  38.502585  {"type": "Topology", "objects": {"data": {"geo...
# 26  -117.240376  32.875794  {"type": "Topology", "objects": {"data": {"geo...
# 27  -118.122245  34.669918  {"type": "Topology", "objects": {"data": {"geo...
# 28  -118.185853  33.779970  {"type": "Topology", "objects": {"data": {"geo...
# 29   -81.688563  30.308202  {"type": "Topology", "objects": {"data": {"geo...
# ..          ...        ...                                                ...
# 370  -81.953395  28.082720  {"type": "Topology", "objects": {"data": {"geo...
# 371  -81.662063  30.344580  {"type": "Topology", "objects": {"data": {"geo...
# 372  -81.428171  26.743879  {"type": "Topology", "objects": {"data": {"geo...
# 373  -84.979256  32.483420  {"type": "Topology", "objects": {"data": {"geo...
# 374  -83.623419  32.848277  {"type": "Topology", "objects": {"data": {"geo...
# 375  -85.173775  34.238176  {"type": "Topology", "objects": {"data": {"geo...
# 376  -82.353129  31.215916  {"type": "Topology", "objects": {"data": {"geo...
# 377  -70.274313  43.656185  {"type": "Topology", "objects": {"data": {"geo...
# 378  -77.398759  35.608537  {"type": "Topology", "objects": {"data": {"geo...
# 379  -78.586460  35.786731  {"type": "Topology", "objects": {"data": {"geo...
# 380 -122.675999  45.520308  {"type": "Topology", "objects": {"data": {"geo...
# 381 -104.827761  41.175801  {"type": "Topology", "objects": {"data": {"geo...
# 382  -72.685020  41.777736  {"type": "Topology", "objects": {"data": {"geo...
# 383  -86.600635  30.415005  {"type": "Topology", "objects": {"data": {"geo...
# 384  -83.436844  41.921901  {"type": "Topology", "objects": {"data": {"geo...
# 385  -72.272767  43.677615  {"type": "Topology", "objects": {"data": {"geo...
# 386  -74.021233  40.646592  {"type": "Topology", "objects": {"data": {"geo...
# 387  -81.254389  32.966148  {"type": "Topology", "objects": {"data": {"geo...
# 388  -86.801443  36.141767  {"type": "Topology", "objects": {"data": {"geo...
# 389 -117.294120  34.105240  {"type": "Topology", "objects": {"data": {"geo...
# 390  -73.038856  41.557437  {"type": "Topology", "objects": {"data": {"geo...
# 391  -80.242317  25.846461  {"type": "Topology", "objects": {"data": {"geo...
# 392  -81.335265  29.931899  {"type": "Topology", "objects": {"data": {"geo...
# 393  -82.927278  32.547189  {"type": "Topology", "objects": {"data": {"geo...
# 394  -83.800919  34.288549  {"type": "Topology", "objects": {"data": {"geo...
# 395  -87.236990  41.619395  {"type": "Topology", "objects": {"data": {"geo...
# 396  -90.089100  29.961585  {"type": "Topology", "objects": {"data": {"geo...
# 397  -93.262401  44.972100  {"type": "Topology", "objects": {"data": {"geo...
# 398  -76.898520  40.285755  {"type": "Topology", "objects": {"data": {"geo...
# 399  -99.490491  27.520101  {"type": "Topology", "objects": {"data": {"geo...
#
#      population
# 0       1301777
# 1        797770
# 2        942217
# 3        495469
# 4        753866
# 5        613681
# 6        711563
# 7        198087
# 8        632171
# 9       1460829
# 10      4630948
# 11      4631777
# 12      1110124
# 13      1116352
# 14       126443
# 15     12564154
# 16       926772
# 17     15065297
# 18      6118534
# 19      6642236
# 20      6606177
# 21      6647621
# 22      5649780
# 23      6637952
# 24      1577962
# 25       532376
# 26      5231390
# 27      1604989
# 28     13682990
# 29      1585643
# ..          ...
# 370     3670450
# 371     1580944
# 372      550802
# 373      638728
# 374      971729
# 375     1444381
# 376      281646
# 377      723109
# 378      700165
# 379     2672656
# 380     2600869
# 381      378860
# 382     3194768
# 383      325176
# 384     2986753
# 385      353625
# 386    16026820
# 387      215052
# 388     2173696
# 389    10574758
# 390     3157029
# 391     4718907
# 392     1502118
# 393      468723
# 394     3454494
# 395     6739206
# 396     1205209
# 397     3466380
# 398     1636555
# 399      727780
#
# [400 rows x 6 columns]

# %%
topojson.Topology()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-52-af630ed228e6> in <module>
# ----> 1 topojson.Topology()
#
# TypeError: __init__() missing 1 required positional argument: 'data'
